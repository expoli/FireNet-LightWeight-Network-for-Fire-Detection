# %%
# 挂载谷歌云盘、云盘里存储了训练数据集
from google.colab import drive
drive.mount('/content/drive/')
# !pwd
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
# /content

# %%
# 修改工作路径、进入数据集所在路径
import os
path = "/content/drive/My Drive/Datasets"
os.chdir(path)
os.listdir(path)
# Out:
# ['Training Dataset.zip', 'results']

# %%
# 因谷歌云盘空间不足，将数据集复制转移至colab /opt 目录
# !rm  "/opt/fire_colab_test" -rf && mkdir -p  "/opt/fire_colab_test"
import os
workpath = "/opt/fire_colab_test"
# 复制数据集
# !cp 'Training Dataset.zip' "/opt/fire_colab_test/"
os.chdir(workpath)
os.listdir(workpath)
# Out:
# ['Training Dataset.zip']

# %%
# 解压数据集
# !unzip 'Training Dataset.zip'
# 查看数据文件夹名称
os.listdir()
# Out:
# Archive:  Training Dataset.zip
#    creating: Training Dataset/
#    creating: Training Dataset/Fire/
#   inflating: Training Dataset/Fire/fire1.jpg
#   inflating: Training Dataset/Fire/fire10.jpg
#   inflating: Training Dataset/Fire/fire100.jpg
#   inflating: Training Dataset/Fire/fire1000.jpg
#   inflating: Training Dataset/Fire/fire1001.jpg
#   inflating: Training Dataset/Fire/fire1002.jpg
#   inflating: Training Dataset/Fire/fire1003.jpg
#   inflating: Training Dataset/Fire/fire1004.jpg
#   inflating: Training Dataset/Fire/fire1005.jpg
#   inflating: Training Dataset/Fire/fire1006.jpg
#   inflating: Training Dataset/Fire/fire1007.jpg
#   inflating: Training Dataset/Fire/fire1008.jpg
#   inflating: Training Dataset/Fire/fire1009.jpg
#   inflating: Training Dataset/Fire/fire101.jpg
#   inflating: Training Dataset/Fire/fire1010.jpg
#   inflating: Training Dataset/Fire/fire1011.jpg
#   inflating: Training Dataset/Fire/fire1012.jpg
#   inflating: Training Dataset/Fire/fire1013.jpg
# ...

# %%
# 克隆项目、python-reformat 特定分支
# !git clone -b python-reformat https://github.com/expoli/FireNet-LightWeight-Network-for-Fire-Detection.git
# Out:
# Cloning into 'FireNet-LightWeight-Network-for-Fire-Detection'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 283 (delta 69), reused 134 (delta 56), pack-reused 135
# Receiving objects: 100% (283/283), 42.10 MiB | 34.00 MiB/s, done.
# Resolving deltas: 100% (126/126), done.

# %%
# 因开发环境问题，无法直接使用 pip install -r requirement.txt 安装、所以直接安装 conda、使用conda进行环境配置
# !wget https://mirrors.tuna.tsinghua.edu.cn/anaconda/miniconda/Miniconda3-latest-Linux-x86_64.sh && bash Miniconda3-latest-Linux-x86_64.sh -bfp /usr/local
# Out:
# --2020-04-13 04:28:42--  https://mirrors.tuna.tsinghua.edu.cn/anaconda/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving mirrors.tuna.tsinghua.edu.cn (mirrors.tuna.tsinghua.edu.cn)... 101.6.8.193, 2402:f000:1:408:8100::1
# Connecting to mirrors.tuna.tsinghua.edu.cn (mirrors.tuna.tsinghua.edu.cn)|101.6.8.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  81.12M  12.7MB/s    in 7.6s
#
# 2020-04-13 04:28:50 (10.6 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
# ...

# %%
# 保证代码的有效性与及时性
# !cd FireNet-LightWeight-Network-for-Fire-Detection && git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 1 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), done.
# From https://github.com/expoli/FireNet-LightWeight-Network-for-Fire-Detection
#    27fd7e9..453e1a6  python-reformat -> origin/python-reformat
# Updating 27fd7e9..453e1a6
# Fast-forward
#  Codes/python-reformat/BinaryNet_data_aug.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# 使用conda导出的环境配置文件创建新环境
# !conda env create -f  FireNet-LightWeight-Network-for-Fire-Detection/requirements.yaml
# !conda env list
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ...
# py-opencv-4.2.0      | 21 KB     | : 100% 1.0/1 [00:00<00:00,  9.65it/s]
# _tflow_select-2.1.0  | 2 KB      | : 100% 1.0/1 [00:00<00:00, 13.04it/s]
# ipywidgets-7.5.1     | 101 KB    | : 100% 1.0/1 [00:00<00:00, 16.14it/s]
# bleach-3.1.4         | 111 KB    | : 100% 1.0/1 [00:00<00:00, 13.89it/s]
# jinja2-2.11.1        | 94 KB     | : 100% 1.0/1 [00:00<00:00, 18.04it/s]
# sqlite-3.30.1        | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  3.10it/s]
# icu-64.2             | 12.6 MB   | : 100% 1.0/1 [00:01<00:00,  1.78s/it]
# libxkbcommon-0.10.0  | 475 KB    | : 100% 1.0/1 [00:00<00:00, 11.54it/s]
# keras-applications-1 | 30 KB     | : 100% 1.0/1 [00:00<00:00, 29.79it/s]
# libgpuarray-0.7.6    | 263 KB    | : 100% 1.0/1 [00:00<00:00, 12.18it/s]
# ...

# %%
# !pwd
# !ls
# 删除不符合要求的图片
# !rm 'Training Dataset/Fire/fire1.jpg' 'Training Dataset/NoFire/nofire631.jpg'
# Out:
# /opt/fire_colab_test
#  FireNet-LightWeight-Network-for-Fire-Detection  'Training Dataset'
#  Miniconda3-latest-Linux-x86_64.sh		 'Training Dataset.zip'

# %%
# 开始训练，使用conda虚拟环境的 python 进行训练
# !/usr/local/envs/tf-gpu3/bin/python FireNet-LightWeight-Network-for-Fire-Detection/Codes/python-reformat/BinaryNet_data_aug.py -d 'Training Dataset' -e 200
# Out:
# Using TensorFlow backend.
# [INFO] initing gpu.....
# 2020-04-13 04:55:35.996026: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-13 04:55:36.020233: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 04:55:36.020858: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-04-13 04:55:36.021155: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-13 04:55:36.023178: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# ...

# %%
# 查看运行结果
# !ls results00/results07/
# Out:
# checkpoint_path  models  tensorboard_log

# %%
# 压缩训练所得模型与结果
# !zip -r results-2020-04-13.zip results00/
# Out:
#   adding: results00/ (stored 0%)
#   adding: results00/results07/ (stored 0%)
#   adding: results00/results07/tensorboard_log/ (stored 0%)
#   adding: results00/results07/tensorboard_log/validation/ (stored 0%)
#   adding: results00/results07/tensorboard_log/validation/events.out.tfevents.1586753785.211ceb52faa8.7876.1543.v2 (deflated 68%)
#   adding: results00/results07/tensorboard_log/validation/events.out.tfevents.1586752603.211ceb52faa8.5816.1543.v2 (deflated 69%)
#   adding: results00/results07/tensorboard_log/train/ (stored 0%)
#   adding: results00/results07/tensorboard_log/train/plugins/ (stored 0%)
#   adding: results00/results07/tensorboard_log/train/plugins/profile/ (stored 0%)
#   adding: results00/results07/tensorboard_log/train/plugins/profile/2020-04-13_04-56-23/ (stored 0%)
#   adding: results00/results07/tensorboard_log/train/plugins/profile/2020-04-13_04-56-23/local.trace (deflated 91%)
# ...

# %%
# 复制进云盘中去
# !ls
# !mkdir -p '/content/drive/My Drive/Datasets/results/'
# !cp results-2020-04-13.zip '/content/drive/My Drive/Datasets/results/'
# 查看是否保存完成
# !ls '/content/drive/My Drive/Datasets/results/'
# Out:
#  FireNet-LightWeight-Network-for-Fire-Detection   results-2020-04-13.zip
#  Miniconda3-latest-Linux-x86_64.sh		 'Training Dataset'
#  results00					 'Training Dataset.zip'
# results-2020-04-12.zip	results-2020-04-13.zip
